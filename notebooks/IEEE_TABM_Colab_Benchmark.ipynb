# %% [markdown]
# # IEEE-CIS TabM Benchmark on Colab
#
# Notebook nay dung de benchmark nhanh mot nhanh `TabM`-style standalone tren Google Colab truoc khi can nhac bat ky fusion nao vao pipeline IEEE chinh.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
GITHUB_REPO = "https://github.com/Thanh-000/FDB1-DoAn.git"
REPO_PARENT = "/content/drive/MyDrive"
REPO_NAME = "FDB1-DoAn"
REPO_DIR = f"{REPO_PARENT}/{REPO_NAME}"

ZIP_PATH = "/content/drive/MyDrive/MVS_XAI_Data/ieee-fraud-detection.zip"
EXTRACT_DIR = "/content/ieee-fraud-detection"

FOLD_INDEX = 0
N_SPLITS = 5
EPOCHS = 10
BATCH_SIZE = 2048
D_TOKEN = 16
HIDDEN_DIM = 256
N_LAYERS = 3
N_MEMBERS = 4
LR = 1e-3

# %%
import os
if os.path.exists(REPO_DIR):
    # %cd "$REPO_DIR"
    # !git pull
else:
    # %cd "$REPO_PARENT"
    # !git clone "$GITHUB_REPO" "$REPO_NAME"
    # %cd "$REPO_DIR"

# %%
import os, zipfile, glob

if not os.path.exists(EXTRACT_DIR):
    os.makedirs(EXTRACT_DIR, exist_ok=True)
    with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(EXTRACT_DIR)

txn_files = glob.glob(f"{EXTRACT_DIR}/**/train_transaction.csv", recursive=True)
id_files = glob.glob(f"{EXTRACT_DIR}/**/train_identity.csv", recursive=True)
print('txn:', txn_files[:1])
print('id :', id_files[:1])

DATA_DIR = os.path.dirname(txn_files[0])
print('DATA_DIR =', DATA_DIR)

# %%
# %cd "$REPO_DIR"
# !pip -q install scikit-learn torch

# %%
import torch, sklearn
print('torch:', torch.__version__)
print('cuda:', torch.cuda.is_available())
print('gpu :', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NO CUDA')
print('sklearn:', sklearn.__version__)

# %%
cmd = [
    'python', 'run_ieee_tabm.py',
    '--data-dir', DATA_DIR,
    '--fold-index', str(FOLD_INDEX),
    '--n-splits', str(N_SPLITS),
    '--epochs', str(EPOCHS),
    '--batch-size', str(BATCH_SIZE),
    '--d-token', str(D_TOKEN),
    '--hidden-dim', str(HIDDEN_DIM),
    '--n-layers', str(N_LAYERS),
    '--n-members', str(N_MEMBERS),
    '--lr', str(LR),
]
print('Running:')
print(' '.join(cmd))

# %%
import subprocess
result = subprocess.run(cmd, text=True, capture_output=True)
print(result.stdout)
print(result.stderr)
print('returncode =', result.returncode)
